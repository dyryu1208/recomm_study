# %% [markdown]
# # Field-aware Factorization Machine
# - xlearn으로 ffm 모델을 학습합니다
# - 주어진 avazu-ctr-prediction 데이터만 사용합니다
# - 모델의 성능은 분류 성능인 logloss로 평가합니다

# %%
# !wget https://github.com/aksnzhy/xlearn/releases/download/v0.4.4/xlearn-0.4.4.tar.gz

# %%
# !pip install xlearn-0.4.4.tar.gz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing ./xlearn-0.4.4.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xlearn==0.4.4) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xlearn==0.4.4) (1.7.3)
# Building wheels for collected packages: xlearn
#   Building wheel for xlearn (setup.py) ... done
#   Created wheel for xlearn: filename=xlearn-0.4.4-py3-none-any.whl size=239290 sha256=ba1cd1bc4adf57d8f61383c4a415445b817f68d2195521b390ff98c5689c9748
#   Stored in directory: /root/.cache/pip/wheels/e3/f6/89/a5fed279e80bf75e7963ff80f58fc180d1e8d95a181266bea4
# Successfully built xlearn
# Installing collected packages: xlearn
# Successfully installed xlearn-0.4.4

# %%
import pandas as pd
import tensorflow as tf
from datetime import datetime, date
import numpy as np
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss
from google.colab import drive
import xlearn as xl
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
drive.mount('/content/drive')
K = tf.keras.backend
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/recomm_study/recomm_code/Recommend_learningspoons/data/avazu-ctr-prediction-20220921T022743Z-001/avazu-ctr-prediction/ad_click.csv'
parse_date = lambda x : datetime.strptime(x, '%y%m%d%H').strftime('%Y-%m-%d')
click_df = pd.read_csv(file_path, parse_dates = ['datetime'], date_parser = parse_date, header=0)
click_df.head()
# Out:
#                      id  click   datetime    C1  banner_pos   site_id  \
# 0  10019071520499579916      0 2014-10-21  1005           0  da79c793
# 1  10025633842336165171      0 2014-10-21  1010           1  85f751fd
# 2  10092735447533755726      0 2014-10-21  1002           0  61a8c644
# 3  10141326312159899433      1 2014-10-21  1005           1  d9750ee7
# 4  10141793556467368079      0 2014-10-21  1005           0  543a539e
#
#   site_domain site_category    app_id app_domain  ... device_type  \
# 0    71ed77a0      f028772b  ecad2386   7801e8d9  ...           1
# 1    c4e18dd6      50e219e0  8c0dcd5a   7801e8d9  ...           4
# 2    948ff336      50e219e0  ecad2386   7801e8d9  ...           0
# 3    98572c79      f028772b  ecad2386   7801e8d9  ...           1
# 4    c7ca3108      3e814130  ecad2386   7801e8d9  ...           1
#
#   device_conn_type    C14  C15  C16   C17  C18  C19  C20  C21
# 0                0  18993  320   50  2161    0   35   -1  157
# 1                0  21665  320   50  2493    3   35   -1  117
# 2                0  19665  320   50  2253    2  303   -1   52
# 3                0  15706  320   50  1722    0   35   -1   79
# 4                0  20362  320   50  2333    0   39   -1  157
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 데이터 로드 및 Preprocessing

# %% [markdown]
# ## FFM 학습 데이터 생성

# %%
click_df = click_df[[
    'click', 'datetime', 'banner_pos', 'site_id', 'site_domain',
    'site_category', 'app_id', 'app_domain', 'app_category',
    'device_model', 'device_type', 'device_conn_type',
    'C1', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'
]]

# %%
# FM에 사용할 피쳐들

feature_col = [
    'banner_pos', 'site_id', 'site_domain','site_category', 'app_id', 'app_domain',
    'app_category', 'device_model', 'device_type', 'device_conn_type',
    'C1', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'
]

for feature in feature_col:
    click_df[feature] = click_df[feature].astype("category")
    click_df[feature] = click_df[feature].cat.codes

# %%
click_df
# Out:
#         click   datetime  banner_pos  site_id  site_domain  site_category  \
# 0           0 2014-10-21           0     1546          767             18
# 1           0 2014-10-21           1      949         1316              5
# 2           0 2014-10-21           0      706         1001              5
# 3           1 2014-10-21           1     1541         1029             18
# 4           0 2014-10-21           0      617         1338              3
# ...       ...        ...         ...      ...          ...            ...
# 199995      0 2014-10-30           1      647          604             18
# 199996      0 2014-10-30           0      949         1316              5
# 199997      0 2014-10-30           0      217         1620              1
# 199998      0 2014-10-30           0     1361         1251              5
# 199999      0 2014-10-30           0      217         1620              1
#
#         app_id  app_domain  app_category  device_model  ...  device_conn_type  \
# 0         1648          43             0          3696  ...                 0
# 1          965          43             3           441  ...                 0
# 2         1648          43             0          1676  ...                 0
# 3         1648          43             0          2011  ...                 0
# 4         1648          43             0          3004  ...                 0
# ...        ...         ...           ...           ...  ...               ...
# 199995    1648          43             0          1272  ...                 0
# 199996     564          91             3          2240  ...                 0
# 199997    1648          43             0           235  ...                 0
# 199998    1648          43             0           121  ...                 0
# 199999    1648          43             0          1651  ...                 0
#
#         C1   C14  C15  C16  C17  C18  C19  C20  C21
# 0        2   375    3    2  102    0    2    0   42
# 1        5   719    3    2  196    3    2    0   39
# 2        1   410    3    2  116    2   21    0   15
# 3        2   202    3    2   51    0    2    0   22
# 4        2   515    3    2  144    0    4    0   42
# ...     ..   ...  ...  ...  ...  ...  ...  ...  ...
# 199995   2  1771    3    2  378    3    8    0    6
# 199996   2   759    3    2  201    3    5   81   16
# 199997   2  1272    3    2  294    0    2    0   14
# 199998   1   291    3    2   91    2    4   56    7
# 199999   2  1072    3    2  237    0   27   61   54
#
# [200000 rows x 21 columns]

# %%
# feature dimension size
feature_dim = {}
for feature in feature_col:
    feature_dim[feature] = click_df[feature].nunique()

# %%
feature_dim
# Out:
# {'banner_pos': 7,
#  'site_id': 1804,
#  'site_domain': 1711,
#  'site_category': 20,
#  'app_id': 1776,
#  'app_domain': 112,
#  'app_category': 22,
#  'device_model': 3751,
#  'device_type': 4,
#  'device_conn_type': 4,
#  'C1': 7,
#  'C14': 1934,
#  'C15': 8,
#  'C16': 9,
#  'C17': 405,
#  'C18': 4,
#  'C19': 65,
#  'C20': 159,
#  'C21': 60}

# %%
print('number of variables:', sum([dim for dim in feature_dim.values()]))
# Out:
# number of variables: 11862

# %%
# 전체 데이터를 ffm의 variable number로 변환

idx = 0
for feature in feature_col:
    click_df[feature] = click_df[feature] + idx
    idx += feature_dim[feature]

click_df
# Out:
#         click   datetime  banner_pos  site_id  site_domain  site_category  \
# 0           0 2014-10-21           0     1553         2578           3540
# 1           0 2014-10-21           1      956         3127           3527
# 2           0 2014-10-21           0      713         2812           3527
# 3           1 2014-10-21           1     1548         2840           3540
# 4           0 2014-10-21           0      624         3149           3525
# ...       ...        ...         ...      ...          ...            ...
# 199995      0 2014-10-30           1      654         2415           3540
# 199996      0 2014-10-30           0      956         3127           3527
# 199997      0 2014-10-30           0      224         3431           3523
# 199998      0 2014-10-30           0     1368         3062           3527
# 199999      0 2014-10-30           0      224         3431           3523
#
#         app_id  app_domain  app_category  device_model  ...  device_conn_type  \
# 0         5190        5361          5430          9148  ...              9207
# 1         4507        5361          5433          5893  ...              9207
# 2         5190        5361          5430          7128  ...              9207
# 3         5190        5361          5430          7463  ...              9207
# 4         5190        5361          5430          8456  ...              9207
# ...        ...         ...           ...           ...  ...               ...
# 199995    5190        5361          5430          6724  ...              9207
# 199996    4106        5409          5433          7692  ...              9207
# 199997    5190        5361          5430          5687  ...              9207
# 199998    5190        5361          5430          5573  ...              9207
# 199999    5190        5361          5430          7103  ...              9207
#
#           C1    C14    C15    C16    C17    C18    C19    C20    C21
# 0       9213   9593  11155  11162  11271  11574  11580  11643  11844
# 1       9216   9937  11155  11162  11365  11577  11580  11643  11841
# 2       9212   9628  11155  11162  11285  11576  11599  11643  11817
# 3       9213   9420  11155  11162  11220  11574  11580  11643  11824
# 4       9213   9733  11155  11162  11313  11574  11582  11643  11844
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 199995  9213  10989  11155  11162  11547  11577  11586  11643  11808
# 199996  9213   9977  11155  11162  11370  11577  11583  11724  11818
# 199997  9213  10490  11155  11162  11463  11574  11580  11643  11816
# 199998  9212   9509  11155  11162  11260  11576  11582  11699  11809
# 199999  9213  10290  11155  11162  11406  11574  11605  11704  11856
#
# [200000 rows x 21 columns]

# %% [markdown]
# ### train / test 데이터 생성

# %%
# 날짜를 기준으로 train과 test 데이터를 나눕니다

train_df = click_df[click_df['datetime'] <= '2014-10-28']
test_df = click_df[click_df['datetime'] > '2014-10-28']

print(len(train_df))
print(len(test_df))
# Out:
# 160052
# 39948

# %%
# xlearn의 ffm 데이터는 ylabel field_1:index_1:value_1 field_2:index_2:value_2 ... 로 만들어야 합니다

with open('./ffm_train.txt', 'w') as f:
    for _, row in train_df.iterrows():
        label = row['click']
        feature = [str(label)]+ [str(field) + ':' + str(elem) + ':1.0' for field, elem in enumerate(row[feature_col].values)]
        f.write(' '.join(feature) + '\n')

# %%
with open('./ffm_test.txt', 'w') as f:
    for _, row in test_df.iterrows():
        label = row['click']
        feature = [str(label)]+ [str(field) + ':' + str(elem) + ':1.0' for field, elem in enumerate(row[feature_col].values)]
        f.write(' '.join(feature) + '\n')

# %% [markdown]
# ## xlearn FFM
# - 참고: xlearn 모델 관련 [하이퍼파라미터](https://xlearn-doc.readthedocs.io/en/latest/all_api/index.html?highlight=create_fm#xlearn-python-api)

# %%
import xlearn as xl
import os
os.environ['USER'] = 'test'
xl.hello()

# %%
# FM 모델 선언
ffm_model = xl.create_ffm()
ffm_model.setTrain("./content/ffm_train.txt")
ffm_model.setValidate("/content/ffm_test.txt")

# 하이퍼파라미터 선언
param = {'task':'binary', 'lr':0.2, 'lambda':0.001, 'k': 4, 'epoch': 100}

# 모델 학습
ffm_model.setTXTModel("./content/ffm_model.txt")
ffm_model.fit(param, "./content/ffm_model.out")

# %%
# test 데이터를 사용하여 학습된 FM 모델로 CTR 예측 => output.txt

ffm_model.setTest("./content/ffm_test.txt")
ffm_model.setSigmoid()
ffm_model.predict("./content/ffm_model.out", "./ffm_output.txt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-41f2d3d3ed62> in <module>
#       1 # test 데이터를 사용하여 학습된 FM 모델로 CTR 예측 => output.txt
#       2
# ----> 3 ffm_model.setTest("./content/ffm_test.txt")
#       4 ffm_model.setSigmoid()
#       5 ffm_model.predict("./content/ffm_model.out", "./ffm_output.txt")
#
# NameError: name 'ffm_model' is not defined

# %% [markdown]
# ### 하이퍼 파라미터 튜닝

# %%
from sklearn.metrics import log_loss

test_click = test_df['click'].values

result = []

for k in [1,2,4,8]:
    for _lambda in [0.0005, 0.001, 0.002]:
        for lr in [0.1, 0.2, 0.3]:
            
            # train
            ffm_model = xl.create_ffm()         
            ffm_model.setTrain("./ffm_train.txt")
            param = {'task':'binary', 'lr':lr, 'lambda':_lambda, 'k':k, 'epoch':30}
            ffm_model.fit(param, "./ffm_model.out")
            
            # test
            ffm_model.setTest("./ffm_test.txt")
            ffm_model.setSigmoid()
            pCTR = ffm_model.predict("./ffm_model.out")
            result.append([k, _lambda, lr, log_loss(test_click, pCTR)])
            print(k, _lambda, lr, log_loss(test_click, pCTR))
            
result_df = pd.DataFrame(result, columns = ['k', 'lambda', 'lr', 'logloss'])
# Out:
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.44 Version --
# ----------------------------------------------------------------------------------------------
#
# [ WARNING    ] Validation file(dataset) not found, xLearn has already disable early-stopping.
# [------------] xLearn uses 32 threads for training task.
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (./ffm_train.txt.bin) found. Skip converting text to binary.
# [------------] Number of Feature: 11857
# [------------] Number of Field: 19
# [------------] Time cost for reading problem: 0.06 (sec)
# [ ACTION     ] Initialize model ...
# [------------] Model size: 6.97 MB
# [------------] Time cost for model initial: 0.01 (sec)
# [ ACTION     ] Start to train ...
# [------------] Epoch      Train log_loss     Time cost (sec)
# [    3%      ]     1            0.422090                0.18
# [    6%      ]     2            0.413855                0.18
# [   10%      ]     3            0.410987                0.18
# [   13%      ]     4            0.409153                0.18
# [   16%      ]     5            0.407774                0.18
# [   20%      ]     6            0.406674                0.18
# [   23%      ]     7            0.405776                0.18
# [   26%      ]     8            0.404970                0.18
# [   30%      ]     9            0.404284                0.18
# [   33%      ]    10            0.403672                0.18
# [   36%      ]    11            0.403122                0.18
# [   40%      ]    12            0.402598                0.18
# [   43%      ]    13            0.402136                0.18
# [   46%      ]    14            0.401675                0.18
# [   50%      ]    15            0.401278                0.18
# [   53%      ]    16            0.400869                0.18
# [   56%      ]    17            0.400485                0.18
# [   60%      ]    18            0.400138                0.18
# [   63%      ]    19            0.399804                0.18
# [   66%      ]    20            0.399470                0.18
# [   70%      ]    21            0.399168                0.18
# [   73%      ]    22            0.398853                0.18
# [   76%      ]    23            0.398558                0.18
# [   80%      ]    24            0.398263                0.18
# [   83%      ]    25            0.397999                0.18
# [   86%      ]    26            0.397723                0.18
# [   90%      ]    27            0.397453                0.18
# [   93%      ]    28            0.397184                0.18
# [   96%      ]    29            0.396920                0.18
# [  100%      ]    30            0.396684                0.18
# [ ACTION     ] Start to save model ...
# [------------] Model file: ./ffm_model.out
# [------------] Time cost for saving model: 0.01 (sec)
# [ ACTION     ] Finish training
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 5.52 (sec)
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.44 Version --
# ----------------------------------------------------------------------------------------------
#
# [------------] xLearn uses 32 threads for prediction task.
# [ ACTION     ] Load model ...
# [------------] Load model from ./ffm_model.out
# [------------] Loss function: cross-entropy
# [------------] Score function: ffm
# [------------] Number of Feature: 11857
# [------------] Number of K: 1
# [------------] Number of field: 19
# [------------] Time cost for loading model: 0.00 (sec)
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (./ffm_test.txt.bin) found. Skip converting text to binary.
# [------------] Time cost for reading problem: 0.01 (sec)
# [ ACTION     ] Start to predict ...
# [------------] The test loss is: 0.402590
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 0.01 (sec)
# 1 0.0005 0.1 0.40258963737843406
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.44 Version --
# ----------------------------------------------------------------------------------------------
#
# [ WARNING    ] Validation file(dataset) not found, xLearn has already disable early-stopping.
# [------------] xLearn uses 32 threads for training task.
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (./ffm_train.txt.bin) found. Skip converting text to binary.
# [------------] Number of Feature: 11857
# [------------] Number of Field: 19
# [------------] Time cost for reading problem: 0.06 (sec)
# [ ACTION     ] Initialize model ...
# [------------] Model size: 6.97 MB
# [------------] Time cost for model initial: 0.01 (sec)
# [ ACTION     ] Start to train ...
# [------------] Epoch      Train log_loss     Time cost (sec)
# [    3%      ]     1            0
# 28  8  0.0005  0.2  0.402678
# 4   1  0.0010  0.2  0.402693
# 25  4  0.0020  0.2  0.402873
# 21  4  0.0010  0.1  0.402901
# 34  8  0.0020  0.2  0.402942
# 16  2  0.0020  0.2  0.402945
# 7   1  0.0020  0.2  0.402950
# 12  2  0.0010  0.1  0.402955
# 14  2  0.0010  0.3  0.402965
# 30  8  0.0010  0.1  0.402973
# 32  8  0.0010  0.3  0.402991
# 17  2  0.0020  0.3  0.402998
# 23  4  0.0010  0.3  0.403020
# 3   1  0.0010  0.1  0.403059
# 8   1  0.0020  0.3  0.403107
# 26  4  0.0020  0.3  0.403124
# 35  8  0.0020  0.3  0.403131
# 2   1  0.0005  0.3  0.403140
# 5   1  0.0010  0.3  0.403273
# 33  8  0.0020  0.1  0.403429
# 20  4  0.0005  0.3  0.403484
# 24  4  0.0020  0.1  0.403498
# 15  2  0.0020  0.1  0.403503
# 11  2  0.0005  0.3  0.403520
# 6   1  0.0020  0.1  0.403637
# 29  8  0.0005  0.3  0.403656

# %% [markdown]
# # Feature Ablation
# - 일반적인 regerssion, classification에 대해서도 어떤 피쳐가 가장 중요한 역할을 하는지 분석합니다
# - Tree 모델의 경우 Feature Importance로 표현하기도 합니다
# - 현업에서 FM, FFM 계열의 모델을 학습할 때 피쳐의 개수를 최대한 줄이고 서빙속도를 빠르게 하는 것이 목표이므로 다양한 피쳐의 조합에 대해서 실험을 하고 가장 중요한 피쳐들만 선택하여 최종 모델을 만듭니다

# %%
# 우리가 사용한 피쳐 종류 => C14와 app_id의 피쳐를 제외하고 성능을 비교해봅시다
feature_dim
# Out:
# {'banner_pos': 7,
#  'site_id': 1804,
#  'site_domain': 1711,
#  'site_category': 20,
#  'app_id': 1776,
#  'app_domain': 112,
#  'app_category': 22,
#  'device_model': 3751,
#  'device_type': 4,
#  'device_conn_type': 4,
#  'C1': 7,
#  'C14': 1934,
#  'C15': 8,
#  'C16': 9,
#  'C17': 405,
#  'C18': 4,
#  'C19': 65,
#  'C20': 159,
#  'C21': 60}

# %% [markdown]
# ## C14 피쳐를 제외했을 때 성능

# %%
no_c14 = [
    'banner_pos', 'site_id', 'site_domain','site_category', 'app_id', 'app_domain',
    'app_category', 'device_model', 'device_type', 'device_conn_type',
    'C1', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'
]

# %%
with open('./no_c14_train.txt', 'w') as f:
    for _, row in train_df.iterrows():
        label = row['click']
        feature = [str(label)]+ [str(field) + ':' + str(elem) + ':1.0' for field, elem in enumerate(row[no_c14].values)]
        f.write(' '.join(feature) + '\n')

# %%
with open('./no_c14_test.txt', 'w') as f:
    for _, row in test_df.iterrows():
        label = row['click']
        feature = [str(label)]+ [str(field) + ':' + str(elem) + ':1.0' for field, elem in enumerate(row[no_c14].values)]
        f.write(' '.join(feature) + '\n')

# %%
# train
ffm_model = xl.create_ffm()         
ffm_model.setTrain("./no_c14_train.txt")
param = {'task':'binary', 'lr' : 0.1, 'lambda': 0.0005, 'k': 8, 'epoch': 30}
ffm_model.fit(param, "./no_c14_model.out")

# test
ffm_model.setTest("./no_c14_test.txt")
ffm_model.setSigmoid()
pCTR = ffm_model.predict("./no_c14_model.out")
print("log_loss: ", log_loss(test_click, pCTR))
# Out:
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.44 Version --
# ----------------------------------------------------------------------------------------------
#
# [ WARNING    ] Validation file(dataset) not found, xLearn has already disable early-stopping.
# [------------] xLearn uses 32 threads for training task.
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (./no_c14_train.txt.bin) found. Skip converting text to binary.
# [------------] Number of Feature: 11857
# [------------] Number of Field: 18
# [------------] Time cost for reading problem: 0.22 (sec)
# [ ACTION     ] Initialize model ...
# [------------] Model size: 13.12 MB
# [------------] Time cost for model initial: 0.29 (sec)
# [ ACTION     ] Start to train ...
# [------------] Epoch      Train log_loss     Time cost (sec)
# [    3%      ]     1            0.422298                0.33
# [    6%      ]     2            0.414463                0.33
# [   10%      ]     3            0.411784                0.32
# [   13%      ]     4            0.410014                0.33
# [   16%      ]     5            0.408728                0.33
# [   20%      ]     6            0.407666                0.34
# [   23%      ]     7            0.406802                0.34
# [   26%      ]     8            0.406046                0.34
# [   30%      ]     9            0.405366                0.32
# [   33%      ]    10            0.404768                0.34
# [   36%      ]    11            0.404230                0.33
# [   40%      ]    12            0.403701                0.34
# [   43%      ]    13            0.403214                0.34
# [   46%      ]    14            0.402760                0.32
# [   50%      ]    15            0.402343                0.34
# [   53%      ]    16            0.401940                0.33
# [   56%      ]    17            0.401527                0.33
# [   60%      ]    18            0.401162                0.34
# [   63%      ]    19            0.400802                0.34
# [   66%      ]    20            0.400461                0.35
# [   70%      ]    21            0.400134                0.35
# [   73%      ]    22            0.399811                0.34
# [   76%      ]    23            0.399466                0.34
# [   80%      ]    24            0.399147                0.34
# [   83%      ]    25            0.398864                0.34
# [   86%      ]    26            0.398553                0.34
# [   90%      ]    27            0.398258                0.34
# [   93%      ]    28            0.397969                0.34
# [   96%      ]    29            0.397655                0.34
# [  100%      ]    30            0.397391                0.33
# [ ACTION     ] Start to save model ...
# [------------] Model file: ./no_c14_model.out
# [------------] Time cost for saving model: 0.02 (sec)
# [ ACTION     ] Finish training
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 10.62 (sec)
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.44 Version --
# ----------------------------------------------------------------------------------------------
#
# [------------] xLearn uses 32 threads for prediction task.
# [ ACTION     ] Load model ...
# [------------] Load model from ./no_c14_model.out
# [------------] Loss function: cross-entropy
# [------------] Score function: ffm
# [------------] Number of Feature: 11857
# [------------] Number of K: 8
# [------------] Number of field: 18
# [------------] Time cost for loading model: 0.00 (sec)
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (./no_c14_test.txt.bin) found. Skip converting text to binary.
# [------------] Time cost for reading problem: 0.01 (sec)
# [ ACTION     ] Start to predict ...
# [------------] The test loss is: 0.401864
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 0.02 (sec)
# log_loss:  0.40186374871559344

# %% [markdown]
# ## app_id 피쳐를 제외했을 때 성능

# %%
no_app_id = [
    'banner_pos', 'site_id', 'site_domain','site_category', 'app_domain',
    'app_category', 'device_model', 'device_type', 'device_conn_type',
    'C1', 'C14', 'C15', 'C16', 'C17', 'C18', 'C19', 'C20', 'C21'
]

# %%
with open('./no_app_id_train.txt', 'w') as f:
    for _, row in train_df.iterrows():
        label = row['click']
        feature = [str(label)]+ [str(field) + ':' + str(elem) + ':1.0' for field, elem in enumerate(row[no_app_id].values)]
        f.write(' '.join(feature) + '\n')

# %%
with open('./no_app_id_test.txt', 'w') as f:
    for _, row in test_df.iterrows():
        label = row['click']
        feature = [str(label)]+ [str(field) + ':' + str(elem) + ':1.0' for field, elem in enumerate(row[no_app_id].values)]
        f.write(' '.join(feature) + '\n')

# %%
# train
ffm_model = xl.create_ffm()         
ffm_model.setTrain("./no_app_id_train.txt")
param = {'task':'binary', 'lr' : 0.1, 'lambda': 0.0005, 'k': 8, 'epoch': 30}
ffm_model.fit(param, "./no_app_id_model.out")

# test
ffm_model.setTest("./no_app_id_test.txt")
ffm_model.setSigmoid()
pCTR = ffm_model.predict("./no_app_id_model.out")
print("log_loss: ", log_loss(test_click, pCTR))
# Out:
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.44 Version --
# ----------------------------------------------------------------------------------------------
#
# [ WARNING    ] Validation file(dataset) not found, xLearn has already disable early-stopping.
# [------------] xLearn uses 32 threads for training task.
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (./no_app_id_train.txt.bin) NOT found. Convert text file to binary file.
# [------------] Number of Feature: 11857
# [------------] Number of Field: 18
# [------------] Time cost for reading problem: 0.36 (sec)
# [ ACTION     ] Initialize model ...
# [------------] Model size: 13.12 MB
# [------------] Time cost for model initial: 0.09 (sec)
# [ ACTION     ] Start to train ...
# [------------] Epoch      Train log_loss     Time cost (sec)
# [    3%      ]     1            0.422584                0.24
# [    6%      ]     2            0.414806                0.24
# [   10%      ]     3            0.412163                0.24
# [   13%      ]     4            0.410461                0.24
# [   16%      ]     5            0.409164                0.24
# [   20%      ]     6            0.408150                0.24
# [   23%      ]     7            0.407296                0.24
# [   26%      ]     8            0.406526                0.24
# [   30%      ]     9            0.405845                0.24
# [   33%      ]    10            0.405253                0.24
# [   36%      ]    11            0.404704                0.24
# [   40%      ]    12            0.404177                0.24
# [   43%      ]    13            0.403721                0.24
# [   46%      ]    14            0.403251                0.24
# [   50%      ]    15            0.402850                0.24
# [   53%      ]    16            0.402441                0.24
# [   56%      ]    17            0.402047                0.24
# [   60%      ]    18            0.401672                0.24
# [   63%      ]    19            0.401314                0.24
# [   66%      ]    20            0.400959                0.24
# [   70%      ]    21            0.400632                0.24
# [   73%      ]    22            0.400293                0.23
# [   76%      ]    23            0.399960                0.24
# [   80%      ]    24            0.399638                0.24
# [   83%      ]    25            0.399336                0.24
# [   86%      ]    26            0.399025                0.24
# [   90%      ]    27            0.398711                0.24
# [   93%      ]    28            0.398399                0.23
# [   96%      ]    29            0.398087                0.24
# [  100%      ]    30            0.397798                0.23
# [ ACTION     ] Start to save model ...
# [------------] Model file: ./no_app_id_model.out
# [------------] Time cost for saving model: 0.00 (sec)
# [ ACTION     ] Finish training
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 7.55 (sec)
# ----------------------------------------------------------------------------------------------
#            _
#           | |
#      __  _| |     ___  __ _ _ __ _ __
#      \ \/ / |    / _ \/ _` | '__| '_ \
#       >  <| |___|  __/ (_| | |  | | | |
#      /_/\_\_____/\___|\__,_|_|  |_| |_|
#
#         xLearn   -- 0.44 Version --
# ----------------------------------------------------------------------------------------------
#
# [------------] xLearn uses 32 threads for prediction task.
# [ ACTION     ] Load model ...
# [------------] Load model from ./no_app_id_model.out
# [------------] Loss function: cross-entropy
# [------------] Score function: ffm
# [------------] Number of Feature: 11857
# [------------] Number of K: 8
# [------------] Number of field: 18
# [------------] Time cost for loading model: 0.00 (sec)
# [ ACTION     ] Read Problem ...
# [------------] First check if the text file has been already converted to binary format.
# [------------] Binary file (./no_app_id_test.txt.bin) NOT found. Convert text file to binary file.
# [------------] Time cost for reading problem: 0.09 (sec)
# [ ACTION     ] Start to predict ...
# [------------] The test loss is: 0.405651
# [ ACTION     ] Clear the xLearn environment ...
# [------------] Total time cost: 0.09 (sec)
# log_loss:  0.40565122034731704
